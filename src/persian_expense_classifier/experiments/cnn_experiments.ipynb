# %%
from persian_expense_classifier.data.data_loader import loadData
from keras.layers import TextVectorization

# %%
X, y = loadData()

X.shape, y.shape
# Out:
# ((75000,), (75000,))

# %%
text_vectorize = TextVectorization(output_sequence_length=20)


# text_vectorize.ada
# TODO: experiment The TextVectorization
